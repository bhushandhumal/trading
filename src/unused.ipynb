# %%
# https://medium.datadriveninvestor.com/visualizing-option-trading-strategies-in-python-35bfa61151d9
# Out:
# Number of trading sessions: 62

# %%
import opstrat as op

# %%
op1={'op_type': 'c', 'strike': 17000, 'tr_type': 's', 'op_pr': 756}
op2={'op_type': 'c', 'strike': 17000, 'tr_type': 'b', 'op_pr': 5.35}
op3={'op_type': 'p', 'strike': 17000, 'tr_type': 's', 'op_pr': 236.15}
op4={'op_type': 'p', 'strike': 17000, 'tr_type': 'b', 'op_pr': 5.52}

op_list=[op1, op3,]
op.multi_plotter(spot=212.26,spot_range=17000, op_list=op_list)
